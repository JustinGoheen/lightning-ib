# %% [markdown]
# Use this notebook to read in your data and determine if any pre-processing needs to be done

# %%
import os
import pyarrow.parquet as pq
import plotly.graph_objects as go
from lightning_ib.metrics import factors

# %%
os.chdir("..")
os.getcwd()
# Out:
# '/Users/justin/Developer/quant/lightning-ib'

# %%
datapath = os.path.join("data", "markets", "raw", "equities", "SPY.pq")
data = pq.read_table(datapath, columns=["Date", "Open", "High", "Low", "Close"], ).to_pandas()

# %% [markdown]
# # Normalized Average True Range

# %%
natr = factors.normalized_average_true_range(data, period=20)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=natr.index, y=natr.expanding().rank(pct=True)))
fig.update_layout(title="NATR Expanding Rank")
fig.show()

# %% [markdown]
# ## Log Returns

# %%
returns = factors.log_returns(data["Close"])

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=returns.index, y=returns))
fig.update_layout(title="Log Returns")
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=returns.index, y=returns.expanding().rank(pct=True)))
fig.update_layout(title="Returns Expanding Rank")
fig.show()

# %% [markdown]
# ## Relative Strength Index

# %%
rsi = factors.relative_strength_index(data["Close"])

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=rsi.index, y=rsi))
fig.update_layout(title="RSI")
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=rsi.index, y=rsi.expanding().rank(pct=True)))
fig.update_layout(title="RSI Expanding Rank")
fig.show()

# %% [markdown]
# ## Rate of Change

# %%
roc = factors.rate_of_change(data["Close"], period=20)

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=roc.index, y=roc))
fig.update_layout(title="Rate of Change")
fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=roc.index, y=roc.expanding().rank(pct=True)))
fig.update_layout(title="Rate of Change Expanding Rank")
fig.show()

# %% [markdown]
# ## Training Dataset

# %%
training_data_path = os.path.join("data", "markets", "training", "training.pq")

# %%
training_data = pq.read_table(training_data_path).to_pandas()

# %%
training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3886 entries, 2007-06-27 to 2022-11-30
# Columns: 161 entries, SPY_NATR_RANK to USO_RTNS_RANK
# dtypes: float64(161)
# memory usage: 4.8+ MB

# %%
training_data.head()
# Out:
#             SPY_NATR_RANK  SPY_AROON_RANK  SPY_RSI_RANK  SPY_ROC_RANK  \
# Date
# 2007-06-27       0.411357        0.036150      0.301385      0.212188
# 2007-06-28       0.413736        0.036278      0.301302      0.217114
# 2007-06-29       0.429402        0.036406      0.305371      0.187431
# 2007-07-02       0.419042        0.054940      0.451979      0.248270
# 2007-07-03       0.403708        0.076785      0.509685      0.303542
#
#             SPY_RTNS_RANK  EWJ_NATR_RANK  EWJ_AROON_RANK  EWJ_RSI_RANK  \
# Date
# 2007-06-27       0.930008       0.024477        0.109081      0.342675
# 2007-06-28       0.456749       0.021277        0.109220      0.303546
# 2007-06-29       0.484990       0.023041        0.109358      0.520737
# 2007-07-02       0.844438       0.033310        0.500354      0.801914
# 2007-07-03       0.655106       0.020900        0.500354      0.771520
#
#             EWJ_ROC_RANK  EWJ_RTNS_RANK  ...  GLD_NATR_RANK  GLD_AROON_RANK  \
# Date                                     ...
# 2007-06-27      0.482086       0.565187  ...       0.379528        0.064567
# 2007-06-28      0.388652       0.433251  ...       0.360063        0.065252
# 2007-06-29      0.420418       0.769718  ...       0.342229        0.065934
# 2007-07-02      0.528703       0.892995  ...       0.344828        0.066614
# 2007-07-03      0.524973       0.435257  ...       0.327074        0.087637
#
#             GLD_RSI_RANK  GLD_ROC_RANK  GLD_RTNS_RANK  USO_NATR_RANK  \
# Date
# 2007-06-27      0.075591      0.310236       0.496942       0.199301
# 2007-06-28      0.177673      0.279874       0.813740       0.160279
# 2007-06-29      0.183673      0.150706       0.451220       0.111111
# 2007-07-02      0.360502      0.242947       0.869102       0.100346
# 2007-07-03      0.286385      0.225352       0.291793       0.041379
#
#             USO_AROON_RANK  USO_RSI_RANK  USO_ROC_RANK  USO_RTNS_RANK
# Date
# 2007-06-27        0.909091      0.905594      0.930070       0.816393
# 2007-06-28        0.994774      0.958188      0.923345       0.761438
# 2007-06-29        0.993056      0.979167      0.920139       0.736156
# 2007-07-02        0.946367      0.982699      0.906574       0.733766
# 2007-07-03        0.944828      0.982759      0.917241       0.508091
#
# [5 rows x 161 columns]
